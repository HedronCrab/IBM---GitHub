# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Carlo Matteo Di Dionisio__
# Data analyst

# %% [markdown]
# *I am interested in data science, I work with it everyday and learning data analysis has enourmously impacted the time and the precision with which I carry my duties*

# %% [markdown]
# ### Given my basic knowledge, the code just below will be simple.

# %%
871996*1
# Out:
# 871996

# %% [markdown]
# 1. Numbered list
# 2. ?
# -  ah, the bulleted item
# 3. and finally,
# ![eli-cecil-hello-everyone-yellow-01.jpg](attachment:4aeafca7-7f5b-4c17-8922-604da971d441.jpg)
